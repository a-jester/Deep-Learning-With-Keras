# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671) # for reproducibility

# network and training
NB_EPOCH = 250 # increased from 20 to 250
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # number of outputs = number of digits
OPTIMIZER = SGD() 
N_HIDDEN = 128
VALIDATION_SPLIT=0.2
DROPOUT = 0.3 # Fraction of the input units to drop

# data: shuffled and split between
(X_train, y_train), (X_test, y_test) = mnist.load_data()
RESHAPED = 784
#
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# Out:
# 60000 train samples
# 10000 test samples

# %%
# Define the model
# N_HIDDEN Layers
# 10 outputs
# final state is softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT)) # randomly drop neurons to increase performance
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES, input_shape=(RESHAPED,)))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 128)               100480
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  activation_2 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
#  activation_3 (Activation)   (None, 10)                0
#
# ...
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])

# Train the model
history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE,
                    epochs=NB_EPOCH,
                    verbose=VERBOSE,
                    validation_split=VALIDATION_SPLIT)

# Evaluate the score and accuracy of the model
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/250
# 2023-03-08 15:10:20.888718: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 150528000 exceeds 10% of free system memory.
# 375/375 [==============================] - 2s 5ms/step - loss: 1.7034 - accuracy: 0.4634 - val_loss: 0.8930 - val_accuracy: 0.8073
# Epoch 2/250
# 375/375 [==============================] - 4s 12ms/step - loss: 0.9127 - accuracy: 0.7181 - val_loss: 0.5328 - val_accuracy: 0.8697
# Epoch 3/250
# 375/375 [==============================] - 2s 5ms/step - loss: 0.6947 - accuracy: 0.7877 - val_loss: 0.4289 - val_accuracy: 0.8876
# Epoch 4/250
# 375/375 [==============================] - 2s 5ms/step - loss: 0.5948 - accuracy: 0.8210 - val_loss: 0.3724 - val_accuracy: 0.9005
# Epoch 5/250
# 375/375 [==============================] - 2s 4ms/step - loss: 0.5331 - accuracy: 0.8389 - val_loss: 0.3401 - val_accuracy: 0.9074
# Epoch 6/250
# ...
